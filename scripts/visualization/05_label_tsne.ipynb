# %%
import time
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import DBSCAN
from pathlib import Path
from ast import literal_eval
from pandarallel import pandarallel
from umap import UMAP
from sklearn.manifold import TSNE
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_pickle("../../results/schembl_summs_v3_vocab_embeddings.pkl")
arr = np.array(df['embeddings'].tolist())


dbscan = DBSCAN(eps = 0.34, min_samples = 1,n_jobs=-1)
dbscan.fit(arr)
df['dbscan'] = dbscan.labels_
# df_grouped = df[['labels', 'dbscan']]

# %%
umap_model = UMAP(n_components=2, verbose=1, metric="euclidean",n_jobs=-1)
umap_results = umap_model.fit_transform(np.array(df["embeddings"].tolist()))
df["label_umap_x"] = umap_results[:,0]
df["label_umap_y"] = umap_results[:,1]
# Out:
# UMAP( verbose=1)
# Wed Aug  9 11:43:38 2023 Construct fuzzy simplicial set
# Wed Aug  9 11:43:38 2023 Finding Nearest Neighbors
# Wed Aug  9 11:43:38 2023 Building RP forest with 14 trees
# Wed Aug  9 11:43:41 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  9 11:43:51 2023 Finished Nearest Neighbor Search
# Wed Aug  9 11:43:53 2023 Construct embedding
# Epochs completed: 100%| ██████████ 200/200 [00:07]
# Wed Aug  9 11:44:02 2023 Finished embedding

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=50, metric="euclidean",n_jobs=-1)
tsne_results = tsne.fit_transform(np.array(df["embeddings"].tolist()))
df["label_tsne_x"] = tsne_results [:,0]
df["label_tsne_y"] = tsne_results [:,1]
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 29854 samples in 0.009s...
# [t-SNE] Computed neighbors for 29854 samples in 20.054s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 29854
# [t-SNE] Computed conditional probabilities for sample 2000 / 29854
# [t-SNE] Computed conditional probabilities for sample 3000 / 29854
# [t-SNE] Computed conditional probabilities for sample 4000 / 29854
# [t-SNE] Computed conditional probabilities for sample 5000 / 29854
# [t-SNE] Computed conditional probabilities for sample 6000 / 29854
# [t-SNE] Computed conditional probabilities for sample 7000 / 29854
# [t-SNE] Computed conditional probabilities for sample 8000 / 29854
# [t-SNE] Computed conditional probabilities for sample 9000 / 29854
# [t-SNE] Computed conditional probabilities for sample 10000 / 29854
# [t-SNE] Computed conditional probabilities for sample 11000 / 29854
# [t-SNE] Computed conditional probabilities for sample 12000 / 29854
# [t-SNE] Computed conditional probabilities for sample 13000 / 29854
# [t-SNE] Computed conditional probabilities for sample 14000 / 29854
# [t-SNE] Computed conditional probabilities for sample 15000 / 29854
# [t-SNE] Computed conditional probabilities for sample 16000 / 29854
# [t-SNE] Computed conditional probabilities for sample 17000 / 29854
# [t-SNE] Computed conditional probabilities for sample 18000 / 29854
# [t-SNE] Computed conditional probabilities for sample 19000 / 29854
# [t-SNE] Computed conditional probabilities for sample 20000 / 29854
# [t-SNE] Computed conditional probabilities for sample 21000 / 29854
# [t-SNE] Computed conditional probabilities for sample 22000 / 29854
# [t-SNE] Computed conditional probabilities for sample 23000 / 29854
# [t-SNE] Computed conditional probabilities for sample 24000 / 29854
# [t-SNE] Computed conditional probabilities for sample 25000 / 29854
# [t-SNE] Computed conditional probabilities for sample 26000 / 29854
# [t-SNE] Computed conditional probabilities for sample 27000 / 29854
# [t-SNE] Computed conditional probabilities for sample 28000 / 29854
# [t-SNE] Computed conditional probabilities for sample 29000 / 29854
# [t-SNE] Computed conditional probabilities for sample 29854 / 29854
# [t-SNE] Mean sigma: 0.180876
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 101.462746
# [t-SNE] KL divergence after 1000 iterations: 2.738305

# %%
# sort df by most common dbscan labels
df = df.sort_values(by=['dbscan'], ascending=False)

print(df["dbscan"].value_counts()[:10])
# Out:
# dbscan
# 87      3170
# 646       71
# 360       67
# 190       59
# 49        39
# 96        38
# 934       36
# 121       34
# 2085      34
# 1399      29
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


# plot tsne using matplotlib
def plot_tsne(df,):
    plt.clf()    

    plt.scatter(df['label_tsne_x'],
                df['label_tsne_y'],
                c="black",
                alpha=0.5,
                s=0.3,
                edgecolors="none",
    )

    clusters = [87, 646, 360, 190, 49, 96, 934, 121, 2085, 1399]
    cluster_names = ["structural", "antilipidemic", "adregnergic", "5-ht", "pi3k", "phosphonic", "siloxane", "alpha", "polymer", "tetrahydronaphthalene" ]
    colors = ["#636EFA", "#EF553B", "#00CC96", "#AB63FA", "#FFA15A", "#19D3F3", "#FF6692", "#B6E880", "#FF97FF", "#FECB52"]
    
    for cluster, color in zip(clusters, colors):
        plt.scatter(df['label_tsne_x'][df['dbscan'] == cluster],
                    df['label_tsne_y'][df['dbscan'] == cluster],
                    c=color,
                    s=1.5,
                    edgecolors="none",
                    )

    plt.xlabel("tsne_x")
    plt.ylabel("tsne_y")
    # make legend
    # override legend markers
    for i, color in enumerate(colors):
        plt.scatter([], [], c=color, alpha=0.5, s=10, label=cluster_names[i])
    
    plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='Cluster', loc='upper right', bbox_to_anchor=(1.5, 1.0),)
    
    # plt.legend(clusters, loc='upper right', bbox_to_anchor=(1.3, 1.0), title="Cluster #")

    plt.xlim(-100, 100)
    plt.ylim(-100, 100)

    plt.savefig("labels_tsne.png", dpi=600, bbox_inches='tight', )


# # plot tsne using matplotlib
# def plot_umap(df,):
#     plt.clf()    
#     plt.scatter(df['label_umap_x'],
#                 df['label_umap_y'],
#                 c="black",
#                 # marker=".",
#                 s=1.5,
#                 edgecolors="none",
#     )
#     plt.xlabel("tsne_x")
#     plt.ylabel("tsne_y")
#     plt.savefig("labels_umap.png", dpi=600, bbox_inches='tight')


plot_tsne(df)
# plot_umap(df)

# %%
# fig = px.scatter(
#         x=df["label_umap_x"],
#         y=df["label_umap_y"],
#         # color by dbscan cluster, categorical
#         # color=df["dbscan"].astype(str),    

    
#         opacity=1,
#         size=2,
#         # line={"color": "#000000"}, # black
#     )
# fig.update_layout(
#     plot_bgcolor='rgba(255,255,255,0.1)'
# )
# fig.update_layout(
#     width=1200,
#     height=1200,
#     # autosize=False,
#     margin=dict(l=0, r=0, b=0, t=0, pad=0),
#     # dark theme
#     template="ggplot2",

# )

# # fig.update_layout(showlegend=False)
# fig.write_html(file="labels_umap.html")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 fig = px.scatter(
#       2         x=df["label_umap_x"],
#       3         y=df["label_umap_y"],
#       4         # color by dbscan cluster, categorical
#       5         # color=df["dbscan"].astype(str),
#       6
#       7
#       8         opacity=1,
#       9         size=2,
#      10         # line={"color": "#000000"}, # black
#      11     )
#      12 fig.update_layout(
#      13     plot_bgcolor='rgba(255,255,255,0.1)'
#      14 )
#      15 fig.update_layout(
#      16     width=1200,
#      17     height=1200,
#    (...)
#      22
#      23 )
#
# File ~/opt/anaconda3/envs/chef/lib/python3.10/site-packages/plotly/express/_chart_types.py:66, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~/opt/anaconda3/envs/chef/lib/python3.10/site-packages/plotly/express/_core.py:2003, in make_figure(args, constructor, trace_patch, layout_patch)
#    2000 layout_patch = layout_patch or {}
#    2001 apply_default_cascade(args)
# -> 2003 args = build_dataframe(args, constructor)
#    2004 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2005     args = process_dataframe_hierarchy(args)
#
# File ~/opt/anaconda3/envs/chef/lib/python3.10/site-packages/plotly/express/_core.py:1412, in build_dataframe(args, constructor)
#    1409     args["color"] = None
#    1410 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1412 df_output, wide_id_vars = process_args_into_dataframe(
#    1413     args, wide_mode, var_name, value_name
#    1414 )
#    1416 # now that `df_output` exists and `args` contains only references, we complete
#    1417 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1418 # df_output
#    1420 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/opt/anaconda3/envs/chef/lib/python3.10/site-packages/plotly/express/_core.py:1190, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1188     df_output[col_name] = to_unindexed_series(real_argument)
#    1189 elif not df_provided:
# -> 1190     raise ValueError(
#    1191         "String or int arguments are only possible when a "
#    1192         "DataFrame or an array is provided in the `data_frame` "
#    1193         "argument. No DataFrame was provided, but argument "
#    1194         "'%s' is of type str or int." % field
#    1195     )
#    1196 # Check validity of column name
#    1197 elif argument not in df_input.columns:
#
# ValueError: String or int arguments are only possible when a DataFrame or an array is provided in the `data_frame` argument. No DataFrame was provided, but argument 'size' is of type str or int.

# %%
# fig=px.scatter(
#         x=df["label_tsne_x"],
#         y=df["label_tsne_y"],
#         # color by dbscan cluster, categorical
#         # color=df["dbscan"].astype(str),    
#         # hover_data=(df["labels"], df["dbscan"]),
    
#         # opacity=1,
#         # size=2,
#         # line={"color": "#000000"}, # black
#     )
# fig.update_layout(
#     plot_bgcolor='rgba(255,255,255,0.1)'
# )
# fig.update_layout(
#     width=1200,
#     height=1200,
#     # autosize=False,
#     margin=dict(l=0, r=0, b=0, t=0, pad=0),
#     # dark theme
#     template="ggplot2",

# )
# # fig.update_layout(showlegend=False)
# fig.write_html(file="labels_tsne.html")
