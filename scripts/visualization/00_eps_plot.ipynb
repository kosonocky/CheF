# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
path = Path("../../results/eps_diffs/")

eps_list = []
n_clusters_list = []

# for file in path, print filename
for file in sorted(path.iterdir()):
    if "eps" in file.name:
        split_file = file.name.split("_")
        eps = float(split_file[1])
        n_clusters = int(split_file[3])
        eps_list.append(eps)
        n_clusters_list.append(n_clusters)

# %%
df = pd.DataFrame()
df["eps"] = eps_list
df["n_clusters"] = n_clusters_list

# %%
plt.style.use('seaborn-darkgrid')
fig = sns.lineplot(x="eps", y="n_clusters", data=df, marker='o', color='orange', linewidth=2, alpha=0.7 )

# get index of 0.340
idx = df.index[df['eps'] == 0.340].tolist()[0]
# plot eps and n_clusters at index in black
plt.plot(df['eps'][idx], df['n_clusters'][idx], 'ko', marker="*", markersize=10, alpha=0.7)

fig.set(xlabel="Epsilon")
fig.set(ylabel="Number of clusters")

# make x range go from 0 to 1
fig.set_xlim(0,1)
fig.set_ylim(0, 30000)
fig.figure.savefig("eps_by_n_clusters.png", dpi=300)
# Out:
# /var/folders/67/6sj3_z4943v4gy9hc27k5vv80000gq/T/ipykernel_44310/810360458.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# /var/folders/67/6sj3_z4943v4gy9hc27k5vv80000gq/T/ipykernel_44310/810360458.py:7: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ko" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df['eps'][idx], df['n_clusters'][idx], 'ko', marker="*", markersize=10, alpha=0.7)
